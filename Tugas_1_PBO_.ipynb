# %% [markdown]
# <a href="https://colab.research.google.com/github/ardianrachman12/PemrogramanBerorientasiObjek/blob/main/Tugas_1_PBO_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAMA : MOHAMAD SYIFA ARDIAN RACHMAN
#
# NIM : 12201780
#
# PRODI : TI A2

# %% [markdown]
# 1. Merapihkan kode

# %%
        System.out.println( "+------------------------+" );
        System.out.println( "|                        |" );
        System.out.println( "| SPBU 212               |" );
        System.out.println( "|                        |" );
        System.out.println( "| 2021-03-29 04:38PM     |" );
        System.out.println( "|                        |" );
        System.out.println( "| MOHAMAD SYIFA ARDIAN R |");
        System.out.println( "| Bensin (L): 10         |" );
        System.out.println( "| Harga/Liter: Rp 2.100  |" );
        System.out.println( "|                        |" );
        System.out.println( "| Harga total: R 21.000  |" );
        System.out.println( "|                        |" );
        System.out.println( "+------------------------+" );

# %% [markdown]
# hasilnya :

# %%
+------------------------+
|                        |
| SPBU 212               |
|                        |
| 2021-03-29 04:38PM     |
|                        |
| MOHAMAD SYIFA ARDIAN R |
| Bensin (L): 10         |
| Harga/Liter: Rp 2.100  |
|                        |
| Harga total: R 21.000  |
|                        |
+------------------------+
